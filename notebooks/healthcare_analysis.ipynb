# %% [markdown]
# # Healthcare Data Analytics Project
#
# Analysis of patient healthcare records using Python and Pandas.

# %%
import pandas as pd

df = pd.read_csv('../data/patient_data.csv')
df.head()

# %%
df.groupby('Diagnosis')['Treatment_Cost'].mean()
